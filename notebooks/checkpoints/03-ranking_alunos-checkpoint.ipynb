# %%
# 1. Importação das bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configurações visuais
sns.set(style='whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)

# %%
# 2. Carregando o dataset já tratado e pronto para o ranking
df_ranking = pd.read_csv('../data/processed/ranking_alunos.csv')
df_ranking.head()
# Out:
#                              Alunos  Física  Gestão de Operações  História  \
# 0  ANA CLARA DE OLIVEIRA DOS SANTOS     4.3                  2.9       5.0
# 1           ANA JÚLIA ANDRADE LOPES    10.0                  7.1       8.0
# 2         ANA JÚLIA DA CRUZ MACHADO     7.1                  4.3       5.0
# 3       ANNA LAURA OLIVEIRA MACHADO    10.0                  5.7       7.0
# 4    ARTHUR AUGUSTO RODRIGUES SILVA    10.0                  8.6       0.0
#
#    Inovação e Des. de Negócios  Projeto Multidisciplinar  Mkt Estratégico  \
# 0                          3.3                      10.0              6.7
# 1                          6.7                      10.0              6.7
# 2                          8.3                      10.0              8.3
# 3                          5.0                       5.0              8.3
# 4                         10.0                       0.0              0.0
#
#    Lingua Inglesa  Lingua Portuguesa  Matemática  Média Final
# ...

# %% [markdown]
# ## 📌 1. Importar bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configurações visuais
sns.set(style='whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# ## 📌 2. Carregar os dados

# %%
df_ranking = pd.read_csv('../data/processed/ranking_alunos.csv')
df_ranking.head()
# Out:
#                              Alunos  Física  Gestão de Operações  História  \
# 0  ANA CLARA DE OLIVEIRA DOS SANTOS     4.3                  2.9       5.0
# 1           ANA JÚLIA ANDRADE LOPES    10.0                  7.1       8.0
# 2         ANA JÚLIA DA CRUZ MACHADO     7.1                  4.3       5.0
# 3       ANNA LAURA OLIVEIRA MACHADO    10.0                  5.7       7.0
# 4    ARTHUR AUGUSTO RODRIGUES SILVA    10.0                  8.6       0.0
#
#    Inovação e Des. de Negócios  Projeto Multidisciplinar  Mkt Estratégico  \
# 0                          3.3                      10.0              6.7
# 1                          6.7                      10.0              6.7
# 2                          8.3                      10.0              8.3
# 3                          5.0                       5.0              8.3
# 4                         10.0                       0.0              0.0
#
#    Lingua Inglesa  Lingua Portuguesa  Matemática  Média Final
# ...

# %%
# Lista de valores que representam níveis, e não nomes de alunos
niveis_desempenho = ['AVANÇADO', 'ADEQUADO', 'BÁSICO', 'ABAIXO DO BÁSICO']

# Filtrar o DataFrame para manter apenas alunos com nomes diferentes dos níveis
df_ranking = df_ranking[~df_ranking['Alunos'].isin(niveis_desempenho)].copy()

# Reiniciar o índice
df_ranking.reset_index(drop=True, inplace=True)

# Visualizar para confirmar
df_ranking.head()
# Out:
#                              Alunos  Física  Gestão de Operações  História  \
# 0  ANA CLARA DE OLIVEIRA DOS SANTOS     4.3                  2.9       5.0
# 1           ANA JÚLIA ANDRADE LOPES    10.0                  7.1       8.0
# 2         ANA JÚLIA DA CRUZ MACHADO     7.1                  4.3       5.0
# 3       ANNA LAURA OLIVEIRA MACHADO    10.0                  5.7       7.0
# 4    ARTHUR AUGUSTO RODRIGUES SILVA    10.0                  8.6       0.0
#
#    Inovação e Des. de Negócios  Projeto Multidisciplinar  Mkt Estratégico  \
# 0                          3.3                      10.0              6.7
# 1                          6.7                      10.0              6.7
# 2                          8.3                      10.0              8.3
# 3                          5.0                       5.0              8.3
# 4                         10.0                       0.0              0.0
#
# ...

# %%
# Lista com os rótulos que queremos remover
mascaras_finais = ['AVANÇADO', 'ADEQUADO', 'BÁSICO', 'ABAIXO DO BÁSICO']

# Filtrar somente os alunos (removendo os níveis)
df_alunos = df_ranking[~df_ranking['Alunos'].isin(mascaras_finais)].copy()

# (Opcional) Também pode guardar os níveis separadamente, caso queira usar depois:
df_niveis = df_ranking[df_ranking['Alunos'].isin(mascaras_finais)].copy()

# (Opcional) Reordenar por ordem alfabética
df_alunos = df_alunos.sort_values(by='Alunos').reset_index(drop=True)

# Verificar
df_alunos.head()
# Out:
#                              Alunos  Física  Gestão de Operações  História  \
# 0  ANA CLARA DE OLIVEIRA DOS SANTOS     4.3                  2.9       5.0
# 1           ANA JÚLIA ANDRADE LOPES    10.0                  7.1       8.0
# 2         ANA JÚLIA DA CRUZ MACHADO     7.1                  4.3       5.0
# 3       ANNA LAURA OLIVEIRA MACHADO    10.0                  5.7       7.0
# 4    ARTHUR AUGUSTO RODRIGUES SILVA    10.0                  8.6       0.0
#
#    Inovação e Des. de Negócios  Projeto Multidisciplinar  Mkt Estratégico  \
# 0                          3.3                      10.0              6.7
# 1                          6.7                      10.0              6.7
# 2                          8.3                      10.0              8.3
# 3                          5.0                       5.0              8.3
# 4                         10.0                       0.0              0.0
#
# ...

# %% [markdown]
# ## 📌 3. Calcular a quantidade de notas 10 por aluno

# %%
# Selecionar colunas de disciplinas
disciplinas = [
    'Física', 'Gestão de Operações', 'História',
    'Inovação e Des. de Negócios', 'Projeto Multidisciplinar',
    'Mkt Estratégico', 'Lingua Inglesa', 'Lingua Portuguesa', 'Matemática'
]

# Criar nova coluna com contagem de notas 10
df_ranking['Notas_10'] = df_ranking[disciplinas].apply(lambda x: (x == 10.0).sum(), axis=1)

# Visualizar com a nova coluna
df_ranking[['Alunos', 'Notas_10', 'Média Final']].head()
# Out:
#                              Alunos  Notas_10  Média Final
# 0  ANA CLARA DE OLIVEIRA DOS SANTOS         1          5.3
# 1           ANA JÚLIA ANDRADE LOPES         2          6.9
# 2         ANA JÚLIA DA CRUZ MACHADO         1          6.6
# 3       ANNA LAURA OLIVEIRA MACHADO         1          7.4
# 4    ARTHUR AUGUSTO RODRIGUES SILVA         2          4.2

# %% [markdown]
# ## 📌 4. Gerar Ranking por Quantidade de Notas 10

# %%
ranking_notas_10 = df_ranking[['Alunos', 'Notas_10']].sort_values(by='Notas_10', ascending=False).reset_index(drop=True)
ranking_notas_10.head(40)
# Out:
#                                       Alunos  Notas_10
# 0                 GABRIELA GUIMARÃES DE LARA         4
# 1                     THUANY ALMEIDA RIBEIRO         4
# 2                 SARA OLIVEIRA MARCAL SILVA         4
# 3                    DANIEL JOSÉ SOUZA COSTA         4
# 4   GABRIEL FELIPE RODRIGUES ROSA BERNARDINO         4
# 5                   MARCOS PAULO DIAS ARAGÃO         3
# 6                 PIETRO QUEIROZ DE OLIVEIRA         3
# 7                      IZABEL SANTOS MARIANO         3
# 8                  GIOVANNA FERNANDES SOARES         3
# 9                         HYAN CAMARGO LEMOS         2
# 10                   ANA JÚLIA ANDRADE LOPES         2
# 11            JOSÉ ANTONIO OLIVEIRA MONTEIRO         2
# 12              JOÃO VICTOR DOURADO DA VEIGA         2
# 13           HILLARY DOS SANTOS LOPES MENDES         2
# 14                   DENISE VIANA DOS SANTOS         2
# 15            ARTHUR AUGUSTO RODRIGUES SILVA         2
# ...

# %% [markdown]
# ## 📌 5. Gerar Ranking por Média Final

# %%
ranking_media = df_ranking[['Alunos', 'Média Final']].sort_values(by='Média Final', ascending=False).reset_index(drop=True)
ranking_media.head(40)
# Out:
#                                       Alunos  Média Final
# 0   GABRIEL FELIPE RODRIGUES ROSA BERNARDINO          9.2
# 1                    DANIEL JOSÉ SOUZA COSTA          9.1
# 2                 GABRIELA GUIMARÃES DE LARA          8.8
# 3                      IZABEL SANTOS MARIANO          8.7
# 4                  GIOVANNA FERNANDES SOARES          8.7
# 5                   MARCOS PAULO DIAS ARAGÃO          8.4
# 6                 SARA OLIVEIRA MARCAL SILVA          8.4
# 7                 PIETRO QUEIROZ DE OLIVEIRA          8.1
# 8           LAYSA ALANE FERREIRA DE OLIVEIRA          8.1
# 9            HILLARY DOS SANTOS LOPES MENDES          7.9
# 10                    THUANY ALMEIDA RIBEIRO          7.9
# 11                        HYAN CAMARGO LEMOS          7.5
# 12               ANNA LAURA OLIVEIRA MACHADO          7.4
# 13          GABRIEL DA SILVA OLIVEIRA FONTES          7.2
# 14               RAFAEL FREITAS PENICHE ROSA          7.1
# ...

# %% [markdown]
# ## 📌 6. Visualizações com Seaborn - Top 10 por Notas 10

# %%
sns.barplot(data=ranking_notas_10.head(10), x='Notas_10', y='Alunos', palette='Blues_d')
plt.title('Top 10 Alunos com Mais Notas 10')
plt.xlabel('Quantidade de Notas 10')
plt.ylabel('Aluno')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\kmila\AppData\Local\Temp\ipykernel_20820\260088656.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=ranking_notas_10.head(10), x='Notas_10', y='Alunos', palette='Blues_d')

# %% [markdown]
# ## 📌 6. Visualizações com Seaborn - Top 10 por Média Final

# %%
sns.barplot(data=ranking_media.head(10), x='Média Final', y='Alunos', palette='Greens_d')
plt.title('Top 10 Alunos com Maior Média Final')
plt.xlabel('Média Final')
plt.ylabel('Aluno')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\kmila\AppData\Local\Temp\ipykernel_20820\3346585552.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=ranking_media.head(10), x='Média Final', y='Alunos', palette='Greens_d')

# %% [markdown]
# ## 📌 7. (Opcional) Salvar rankings como arquivos CSV

# %%
ranking_notas_10.to_csv('../data/processed/ranking_notas_10.csv', index=False)
ranking_media.to_csv('../data/processed/ranking_media_final.csv', index=False)
